# %%
import pandas as pd
df = pd.read_csv("../data/raw/student_performance_500.csv")
df.head()
# Out:
#    attendance  study_hours  previous_score  assignments extracurricular  \
# 0          78            2              33            8              No
# 1          91           17              91            2             Yes
# 2          68           12              91            3              No
# 3          54            6              53            9             Yes
# 4          82            3              84            0             Yes
#
#   internet  sleep_hours performance
# 0      Yes            7         Low
# 1      Yes            8        High
# 2      Yes            4      Medium
# 3      Yes            7      Medium
# 4      Yes            4         Low

# %%
df.head()
# Out:
#    attendance  study_hours  previous_score  assignments extracurricular  \
# 0          78            2              33            8              No
# 1          91           17              91            2             Yes
# 2          68           12              91            3              No
# 3          54            6              53            9             Yes
# 4          82            3              84            0             Yes
#
#   internet  sleep_hours performance
# 0      Yes            7         Low
# 1      Yes            8        High
# 2      Yes            4      Medium
# 3      Yes            7      Medium
# 4      Yes            4         Low

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   attendance       500 non-null    int64
#  1   study_hours      500 non-null    int64
#  2   previous_score   500 non-null    int64
#  3   assignments      500 non-null    int64
#  4   extracurricular  500 non-null    object
#  5   internet         500 non-null    object
#  6   sleep_hours      500 non-null    int64
#  7   performance      500 non-null    object
# dtypes: int64(5), object(3)
# memory usage: 31.4+ KB

# %%
df.describe()
# Out:
#        attendance  study_hours  previous_score  assignments  sleep_hours
# count  500.000000   500.000000      500.000000   500.000000   500.000000
# mean    70.784000    10.106000       64.252000     4.924000     6.490000
# std     17.589546     6.195444       20.366002     3.227236     1.722741
# min     40.000000     0.000000       30.000000     0.000000     4.000000
# 25%     57.000000     4.000000       46.000000     2.000000     5.000000
# 50%     71.500000    11.000000       65.000000     5.000000     7.000000
# 75%     86.000000    16.000000       82.000000     8.000000     8.000000
# max    100.000000    20.000000      100.000000    10.000000     9.000000

# %%
df['performance'].value_counts()
# Out:
# performance
# High      171
# Medium    165
# Low       164
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()
